# %%
import os
import random
import numpy as np
import tensorflow as tf

seed = 42
os.environ["PYTHONHASHSEED"] = str(seed)
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

print(tf.__version__)
print("GPU Available:", len(tf.config.list_physical_devices("GPU")) > 0)
print(tf.config.list_physical_devices("GPU"))
# Out:
# 2.19.0
# GPU Available: True
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

base_dir = "/kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray"  

train_dir = os.path.join(base_dir, "train")
test_dir = os.path.join(base_dir, "test")
val_dir = os.path.join(base_dir, "val")

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(rescale=1./255)

img_height, img_width = 224, 224
batch_size = 32

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary'
)

val_generator = test_datagen.flow_from_directory(
    val_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 5216 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
import numpy as np

classes = list(train_generator.class_indices.keys())
train_counts = [len(os.listdir(os.path.join(train_dir, cls))) for cls in classes]

plt.bar(classes, train_counts)
plt.title("Number of Images per Class in Train Set")
plt.show()

sample_imgs = []
for cls in classes:
    cls_dir = os.path.join(train_dir, cls)
    sample_imgs.extend([os.path.join(cls_dir, img) for img in os.listdir(cls_dir)][:5])

plt.figure(figsize=(15,5))
for i, img_path in enumerate(sample_imgs):
    img = image.load_img(img_path, target_size=(img_height, img_width))
    plt.subplot(2,5,i+1)
    plt.imshow(img)
    plt.axis('off')
plt.show()

dims = []
for cls in classes:
    cls_dir = os.path.join(train_dir, cls)
    for img_file in os.listdir(cls_dir):
        img_path = os.path.join(cls_dir, img_file)
        img_obj = image.load_img(img_path)
        dims.append(img_obj.size)

dims = np.array(dims)
print("Image dimensions statistics (width x height):")
print("Min:", dims.min(axis=0))
print("Max:", dims.max(axis=0))
print("Mean:", dims.mean(axis=0))
# Out:
# Image dimensions statistics (width x height):
# Min: [384 127]
# Max: [2916 2663]
# Mean: [1320.61081288  968.07476994]

# %%
import os

base_dir = "/kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray"

train_dir = os.path.join(base_dir, "train")
test_dir = os.path.join(base_dir, "test")

print(os.listdir(base_dir))
print(os.listdir(train_dir))
print(os.listdir(test_dir))
# Out:
# ['chest_xray', '__MACOSX', 'val', 'test', 'train']
# ['PNEUMONIA', 'NORMAL']
# ['PNEUMONIA', 'NORMAL']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

img_height, img_width = 224, 224
batch_size = 32

datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode="nearest",
    validation_split=0.2
)

train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode="binary",
    subset="training"
)

val_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode="binary",
    subset="validation"
)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode="binary",
    shuffle=False
)
# Out:
# Found 4173 images belonging to 2 classes.
# Found 1043 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
from tensorflow.keras import layers, models, optimizers

model = models.Sequential([
    layers.Conv2D(32, (3,3), activation='relu', input_shape=(224,224,3)),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2,2),

    layers.Conv2D(64, (3,3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2,2),

    layers.Conv2D(128, (3,3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2,2),

    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(1, activation='sigmoid')
])

model.compile(
    optimizer=optimizers.Adam(learning_rate=0.0001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1771612688.046997      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1771612688.053252      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 222, 222, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 109, 109, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 52, 52, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 110,785 (432.75 KB)
#  Trainable params: 110,337 (431.00 KB)
#  Non-trainable params: 448 (1.75 KB)

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

classes = train_generator.classes
class_weights = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(classes),
    y=classes
)

class_weights = dict(enumerate(class_weights))
print(class_weights)
# Out:
# {0: np.float64(1.9445479962721341), 1: np.float64(0.6730645161290323)}

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=3,
    min_lr=1e-6
)

checkpoint = ModelCheckpoint(
    "best_model.keras",
    monitor='val_loss',
    save_best_only=True
)

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=25,
    class_weight=class_weights,
    callbacks=[early_stop, reduce_lr, checkpoint]
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/25
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771598907.785791     123 service.cc:152] XLA service 0x7843340087a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1771598907.785843     123 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:
25
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 90s 684ms/step - accuracy: 0.9179 - loss: 0.1959 - val_accuracy: 0.9175 - val_loss: 0.2090 - learning_rate: 2.7000e-06

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import numpy as np

test_generator.reset()
pred_probs = model.predict(test_generator)
preds = (pred_probs > 0.5).astype(int).reshape(-1)

true_labels = test_generator.classes

print(classification_report(true_labels, preds))

cm = confusion_matrix(true_labels, preds)
print("Confusion Matrix:")
print(cm)

auc = roc_auc_score(true_labels, pred_probs)
print("ROC-AUC:", auc)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 475ms/step
#               precision    recall  f1-score   support
#
#            0       0.74      0.76      0.75       234
#            1       0.85      0.84      0.85       390
#
#     accuracy                           0.81       624
#    macro avg       0.80      0.80      0.80       624
# weighted avg       0.81      0.81      0.81       624
#
# Confusion Matrix:
# [[177  57]
#  [ 62 328]]
# ROC-AUC: 0.8949813719044488

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras import layers, models, optimizers

base_model = EfficientNetB0(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

base_model.trainable = False

model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.BatchNormalization(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(1, activation='sigmoid')
])

model.compile(
    optimizer=optimizers.Adam(learning_rate=1e-4),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 1280)           │         5,120 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,218,788 (16.09 MB)
#  Trainable params: 166,657 (651.00 KB)
#  Non-trainable params: 4,052,131 (15.46 MB)

# %%
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    validation_split=0.2
)

train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode="binary",
    subset="training"
)

val_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode="binary",
    subset="validation"
)

test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode="binary",
    shuffle=False
)
# Out:
# Found 4173 images belonging to 2 classes.
# Found 1043 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=4,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.3,
    patience=2,
    min_lr=1e-6,
    verbose=1
)

checkpoint = ModelCheckpoint(
    "best_efficientnet_model.keras",
    monitor="val_loss",
    save_best_only=True,
    verbose=1
)

# %%
history_stage1 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=10,
    class_weight=class_weights,
    callbacks=[early_stop, reduce_lr, checkpoint]
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771612883.339430     172 service.cc:152] XLA service 0x7b8ffc114820 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1771612883.339481     172 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1771612883.339489     172 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1771612886.066304     172 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-02-20 18:41:33.917282: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-20 18:41:34.061999: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-20 18:41:34.409291: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-20 18:41:34.552969: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-20 18:41:35.358805: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-20 18:41:35.500713: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1771612902.565868     172 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#   7/131 ━━━━━━━━━━━━━━━━━━━━ 1:06 537ms/step - accuracy: 0.4998 - loss: 0.8444
# 2026-02-20 18:41:54.461709: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-20 18:41:54.600821: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-20 18:41:54.929016: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-20 18:41:55.071103: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-20 18:41:55.859886: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-20 18:41:56.002004: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 781ms/step - accuracy: 0.7048 - loss: 0.5489
# 2026-02-20 18:43:59.253744: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-20 18:43:59.394675: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-20 18:43:59.725654: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-20 18:43:59.867792: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-20 18:44:00.637469: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-20 18:44:00.779623: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Epoch 1: val_loss improved from inf to 0.29308, saving model to best_efficientnet_model.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 174s 1s/step - accuracy: 0.7054 - loss: 0.5478 - val_accuracy: 0.9262 - val_loss: 0.2931 - learning_rate: 1.0000e-04
# Epoch 2/10
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 654ms/step - accuracy: 0.8838 - loss: 0.2496
# Epoch 2: val_loss improved from 0.29308 to 0.20078, saving model to best_efficientnet_model.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 108s 827ms/step - accuracy: 0.8838 - loss: 0.2496 - val_accuracy: 0.9386 - val_loss: 0.2008 - learning_rate: 1.0000e-04
# Epoch 3/10
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 650ms/step - accuracy: 0.9062 - loss: 0.2182
# Epoch 3: val_loss improved from 0.20078 to 0.16917, saving model to best_efficientnet_model.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 108s 823ms/step - accuracy: 0.9062 - loss: 0.2181 - val_accuracy: 0.9338 - val_loss: 0.1692 - learning_rate: 1.0000e-04
# Epoch 4/10
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 655ms/step - accuracy: 0.9189 - loss: 0.1807
# Epoch 4: val_loss improved from 0.16917 to 0.15564, saving model to best_efficientnet_model.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 108s 829ms/step - accuracy: 0.9188 - loss: 0.1808 - val_accuracy: 0.9348 - val_loss: 0.1556 - learning_rate: 1.0000e-04
# Epoch 5/10
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 655ms/step - accuracy: 0.9275 - loss: 0.1693
# Epoch 5: val_loss did not improve from 0.15564
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 108s 822ms/step - accuracy: 0.9275 - loss: 0.1693 - val_accuracy: 0.9300 - val_loss: 0.1570 - learning_rate: 1.0000e-04
# Epoch 6/10
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 670ms/step - accuracy: 0.9192 - loss: 0.1707
# Epoch 6: val_loss improved from 0.15564 to 0.15431, saving model to best_efficientnet_model.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 111s 845ms/step - accuracy: 0.9192 - loss: 0.1708 - val_accuracy: 0.9348 - val_loss: 0.1543 - learning_rate: 1.0000e-04
# Epoch 7/10
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 661ms/step - accuracy: 0.9371 - loss: 0.1604
# Epoch 7: val_loss improved from 0.15431 to 0.15032, saving model to best_efficientnet_model.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 110s 838ms/step - accuracy: 0.9370 - loss: 0.1604 - val_accuracy: 0.9367 - val_loss: 0.1503 - learning_rate: 1.0000e-04
# Epoch 8/10
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 668ms/step - accuracy: 0.9298 - loss: 0.1574
# Epoch 8: val_loss improved from 0.15032 to 0.14905, saving model to best_efficientnet_model.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 110s 839ms/step - accuracy: 0.9298 - loss: 0.1573 - val_accuracy: 0.9367 - val_loss: 0.1490 - learning_rate: 1.0000e-04
# Epoch 9/10
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 657ms/step - accuracy: 0.9348 - loss: 0.1549
# Epoch 9: val_loss improved from 0.14905 to 0.12520, saving model to best_efficientnet_model.keras
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 109s 831ms/step - accuracy: 0.9348 - loss: 0.1548 - val_accuracy: 0.9530 - val_loss: 0.1252 - learning_rate: 1.0000e-04
# Epoch 10/10
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 671ms/step - accuracy: 0.9419 - loss: 0.1343
# Epoch 10: val_loss did not improve from 0.12520
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 110s 838ms/step - accuracy: 0.9419 - loss: 0.1343 - val_accuracy: 0.9511 - val_loss: 0.1270 - learning_rate: 1.0000e-04

# %%
base_model = model.layers[0]

for layer in base_model.layers[-40:]:
    layer.trainable = True

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# %%
history_stage2 = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=10,
    class_weight=class_weights,
    callbacks=[early_stop, reduce_lr, checkpoint]
)
# Out:
# Epoch 1/10
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 770ms/step - accuracy: 0.8969 - loss: 0.2562
# Epoch 1: val_loss did not improve from 0.12520
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 170s 1s/step - accuracy: 0.8969 - loss: 0.2561 - val_accuracy: 0.9137 - val_loss: 0.2312 - learning_rate: 1.0000e-05
# Epoch 2/10
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 668ms/step - accuracy: 0.9161 - loss: 0.1942
# Epoch 2: val_loss did not improve from 0.12520
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 110s 835ms/step - accuracy: 0.9160 - loss: 0.1942 - val_accuracy: 0.9070 - val_loss: 0.2017 - learning_rate: 1.0000e-05
# Epoch 3/10
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 661ms/step - accuracy: 0.9190 - loss: 0.1783
# Epoch 3: val_loss did not improve from 0.12520
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 108s 827ms/step - accuracy: 0.9190 - loss: 0.1783 - val_accuracy: 0.9310 - val_loss: 0.1553 - learning_rate: 1.0000e-05
# Epoch 4/10
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 669ms/step - accuracy: 0.9289 - loss: 0.1787
# Epoch 4: val_loss did not improve from 0.12520
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 110s 838ms/step - accuracy: 0.9289 - loss: 0.1786 - val_accuracy: 0.9252 - val_loss: 0.1708 - learning_rate: 1.0000e-05
# Epoch 5/10
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 662ms/step - accuracy: 0.9241 - loss: 0.1818
# Epoch 5: val_loss did not improve from 0.12520
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 108s 827ms/step - accuracy: 0.9241 - loss: 0.1817 - val_accuracy: 0.9386 - val_loss: 0.1530 - learning_rate: 1.0000e-05
# Epoch 6/10
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 660ms/step - accuracy: 0.9322 - loss: 0.1474
# Epoch 6: val_loss did not improve from 0.12520
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 108s 827ms/step - accuracy: 0.9322 - loss: 0.1475 - val_accuracy: 0.9415 - val_loss: 0.1473 - learning_rate: 1.0000e-05
# Epoch 7/10
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 664ms/step - accuracy: 0.9320 - loss: 0.1721
# Epoch 7: val_loss did not improve from 0.12520
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 109s 829ms/step - accuracy: 0.9320 - loss: 0.1720 - val_accuracy: 0.9358 - val_loss: 0.1587 - learning_rate: 1.0000e-05
# Epoch 8/10
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 656ms/step - accuracy: 0.9341 - loss: 0.1659
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.9999999242136253e-06.
#
# Epoch 8: val_loss did not improve from 0.12520
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 108s 826ms/step - accuracy: 0.9341 - loss: 0.1659 - val_accuracy: 0.9348 - val_loss: 0.1472 - learning_rate: 1.0000e-05
# Epoch 9/10
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 657ms/step - accuracy: 0.9379 - loss: 0.1447
# Epoch 9: val_loss did not improve from 0.12520
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 108s 826ms/step - accuracy: 0.9379 - loss: 0.1448 - val_accuracy: 0.9453 - val_loss: 0.1517 - learning_rate: 3.0000e-06
# Epoch 10/10
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 662ms/step - accuracy: 0.9354 - loss: 0.1497
# Epoch 10: val_loss did not improve from 0.12520
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 108s 827ms/step - accuracy: 0.9354 - loss: 0.1497 - val_accuracy: 0.9444 - val_loss: 0.1354 - learning_rate: 3.0000e-06

# %%
model.load_weights("best_efficientnet_model.keras")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 86 variables whereas the saved optimizer has 14 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
import numpy as np

y_true = test_generator.classes
y_prob = model.predict(test_generator).ravel()
y_pred = (y_prob >= 0.5).astype(int)
# Out:
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step
# 2026-02-20 19:27:23.033660: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-20 19:27:23.173754: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-20 19:27:23.500464: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-20 19:27:23.641894: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-20 19:27:23.783383: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-20 19:27:24.573797: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-20 19:27:24.715604: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step

# %%
from sklearn.metrics import classification_report

print(classification_report(
    y_true,
    y_pred,
    target_names=["Normal", "Pneumonia"]
))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.88      0.88      0.88       234
#    Pneumonia       0.93      0.93      0.93       390
#
#     accuracy                           0.91       624
#    macro avg       0.90      0.90      0.90       624
# weighted avg       0.91      0.91      0.91       624

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt="d",
            xticklabels=["Normal", "Pneumonia"],
            yticklabels=["Normal", "Pneumonia"],
            cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - Medical Diagnosis")
plt.show()

# %%
threshold = 0.35
y_pred_opt = (y_prob >= threshold).astype(int)
